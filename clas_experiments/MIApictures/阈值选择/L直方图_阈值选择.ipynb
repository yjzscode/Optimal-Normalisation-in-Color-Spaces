# %%
import cv2
import numpy as np
import numpy.linalg as npl
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import sympy
from sympy import *
from IPython.core.interactiveshell import InteractiveShell
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_blobs
from sklearn.neighbors import KernelDensity
import itertools as it
import seaborn as sns
import scipy
from scipy import stats
from scipy.stats import gaussian_kde
from scipy.stats import multivariate_normal
from matplotlib.gridspec import GridSpec
from matplotlib import cm
import math
from scipy.integrate import trapz
import os
import torch
from tqdm import tqdm
import numpy as np
import random
from datetime import datetime
import time
from omegaconf import OmegaConf
from torchvision import transforms
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.optim import AdamW
from torch.optim import lr_scheduler
import pandas as pd
import torchvision
from set import HistoDataset
from torch import nn
import torch
from kornia.color import lab_to_rgb, rgb_to_lab, hsv_to_rgb, rgb_to_hsv
from einops import repeat
# from model.hed import hed_to_rgb, rgb_to_hed

from matplotlib import pyplot as plt
import cv2
import numpy as np
img = cv2.imread('/root/autodl-tmp/MIApictures/ADI-AAPLSLRK.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_LAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
img_LAB1 = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

img_LAB0 = (np.round(cv2.cvtColor(img, cv2.COLOR_BGR2LAB)/2.55)).astype(np.uint8)
# print(img_LAB0)

for i in range(np.shape(img)[0]):
    for j in range(np.shape(img)[1]):
        if img_LAB[i][j][0] > 230:
            img_LAB[i][j][0] = 0
img0 = cv2.cvtColor(img_LAB, cv2.COLOR_LAB2RGB)
plt.imshow(img0)
plt.savefig("img0.png")
plt.show()

for i in range(np.shape(img)[0]):
    for j in range(np.shape(img)[1]):
        if img_LAB1[i][j][0] < 230:
            img_LAB1[i][j][0] = 0
img1 = cv2.cvtColor(img_LAB1, cv2.COLOR_LAB2RGB)
plt.imshow(img1)
plt.savefig("img1.png")
plt.show()

plt.imshow(img_rgb)
plt.savefig("img2.png")
plt.show()
hist = cv2.calcHist([img_LAB0], [0], None, [100], [0, 100])

plt.figure()
plt.axvline(90,color = "orange",label ='L = 82')
plt.title("L channel Histogram", fontsize=15)
plt.xlabel("Values of L Channel", fontsize=15)

plt.ylabel("Number of Pixels", fontsize=15)
plt.plot(hist,label ='Number of Pixels')
plt.xlim([0, 100])
plt.savefig("img3.png")
plt.show()

# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np
img = cv2.imread('/root/autodl-tmp/MIApictures/NORM-TCGA-DAKDQWRM.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_LAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
img_LAB1 = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

img_LAB0 = (np.round(cv2.cvtColor(img, cv2.COLOR_BGR2LAB)/2.55)).astype(np.uint8)
# print(img_LAB0)

for i in range(np.shape(img)[0]):
    for j in range(np.shape(img)[1]):
        if img_LAB[i][j][0] > 230:
            img_LAB[i][j][0] = 0
img0 = cv2.cvtColor(img_LAB, cv2.COLOR_LAB2RGB)
plt.imshow(img0)
plt.show()

for i in range(np.shape(img)[0]):
    for j in range(np.shape(img)[1]):
        if img_LAB1[i][j][0] < 230:
            img_LAB1[i][j][0] = 0
img1 = cv2.cvtColor(img_LAB1, cv2.COLOR_LAB2RGB)
plt.imshow(img1)
plt.show()

plt.imshow(img_rgb)
plt.show()
hist = cv2.calcHist([img_LAB0], [0], None, [100], [0, 100])

plt.figure()
plt.axvline(90,color = "orange",label ='L = 82')
plt.title("L channel Histogram", fontsize=15)
plt.xlabel("Values of L Channel", fontsize=15)

plt.ylabel("Number of Pixels", fontsize=15)
plt.plot(hist,label ='Number of Pixels')
plt.xlim([0, 100])
plt.show()

# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np
img = cv2.imread('/root/autodl-tmp/MIApictures/NORM-TCGA-CVFGMNNY.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_LAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
img_LAB1 = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

img_LAB0 = (np.round(cv2.cvtColor(img, cv2.COLOR_BGR2LAB)/2.55)).astype(np.uint8)
# print(img_LAB0)

for i in range(np.shape(img)[0]):
    for j in range(np.shape(img)[1]):
        if img_LAB[i][j][0] > 169:
            img_LAB[i][j][0] = 0
img0 = cv2.cvtColor(img_LAB, cv2.COLOR_LAB2RGB)
plt.imshow(img0)
plt.savefig("img00.png")
plt.show()

for i in range(np.shape(img)[0]):
    for j in range(np.shape(img)[1]):
        if img_LAB1[i][j][0] < 169:
            img_LAB1[i][j][0] = 0
img1 = cv2.cvtColor(img_LAB1, cv2.COLOR_LAB2RGB)
plt.imshow(img1)
plt.savefig("img01.png")
plt.show()

plt.imshow(img_rgb)
plt.savefig("img02.png")
plt.show()
hist = cv2.calcHist([img_LAB0], [0], None, [100], [0, 100])

plt.figure()
plt.axvline(90,color = "orange",label ='L = 82')
plt.title("L channel Histogram", fontsize=15)
plt.xlabel("Values of L Channel", fontsize=15)

plt.ylabel("Number of Pixels", fontsize=15)
plt.plot(hist,label ='Number of Pixels')
plt.xlim([0, 100])
plt.savefig("img03.png")
plt.show()

# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np
img = cv2.imread('/root/autodl-tmp/MIApictures/TUM-TCGA-ARTHKYNY.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_LAB = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
img_LAB1 = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

img_LAB0 = (np.round(cv2.cvtColor(img, cv2.COLOR_BGR2LAB)/2.55)).astype(np.uint8)
# print(img_LAB0)

for i in range(np.shape(img)[0]):
    for j in range(np.shape(img)[1]):
        if img_LAB[i][j][0] > 230:
            img_LAB[i][j][0] = 0
img0 = cv2.cvtColor(img_LAB, cv2.COLOR_LAB2RGB)
plt.imshow(img0)
plt.show()

for i in range(np.shape(img)[0]):
    for j in range(np.shape(img)[1]):
        if img_LAB1[i][j][0] < 230:
            img_LAB1[i][j][0] = 0
img1 = cv2.cvtColor(img_LAB1, cv2.COLOR_LAB2RGB)
plt.imshow(img1)
plt.show()

plt.imshow(img_rgb)
plt.show()
hist = cv2.calcHist([img_LAB0], [0], None, [100], [0, 100])

plt.figure()
plt.axvline(90,color = "orange",label ='L = 82')
plt.title("L channel Histogram", fontsize=15)
plt.xlabel("Values of L Channel", fontsize=15)

plt.ylabel("Number of Pixels", fontsize=15)
plt.plot(hist,label ='Number of Pixels')
plt.xlim([0, 100])
plt.show()

# %%
#选取230为阈值 [0,100]选取90
