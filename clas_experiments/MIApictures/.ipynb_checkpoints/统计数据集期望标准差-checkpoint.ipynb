# %%
import numpy as np
import numpy.linalg as npl
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import sympy
from sympy import *
from IPython.core.interactiveshell import InteractiveShell
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_blobs
from sklearn.neighbors import KernelDensity
import itertools as it
import seaborn as sns
import scipy
from scipy import stats
from scipy.stats import gaussian_kde
from scipy.stats import multivariate_normal
from matplotlib.gridspec import GridSpec
from matplotlib import cm
import math
from scipy.integrate import trapz
import os
import torch
from tqdm import tqdm
import numpy as np
import random
from datetime import datetime
import time
from omegaconf import OmegaConf
from torchvision import transforms
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.optim import AdamW
from torch.optim import lr_scheduler
import pandas as pd
import torchvision
from set import HistoDataset
from torch import nn
import torch
from kornia.color import lab_to_rgb, rgb_to_lab, hsv_to_rgb, rgb_to_hsv
from einops import repeat
# from model.hed import hed_to_rgb, rgb_to_hed

# %%
# Figure setup.
fig = plt.figure(figsize=(14, 12))
gs = GridSpec(2, 2, width_ratios=[4, 1], height_ratios=[1, 4])
ax1 = fig.add_subplot(gs[0])
ax3 = fig.add_subplot(gs[2])
ax3.axis('equal')
ax4 = fig.add_subplot(gs[3])
bins = 100
# Figure setup.

# Central scatter plot.
ax3.scatter(data[:,0],data[:,1], s = .5, alpha = .5)
sns.kdeplot(data[:,0], data[:,1],n_levels=10, cmap="viridis_r", ax = ax3, bw = 1)
ax3.scatter(np.mean(data[:,0]),np.mean(data[:,1]), marker = "o", color = "magenta")
ax3.scatter(max(set(first[:,0]), key=list(first[:,0]).count), max(set(first[:,1]), key=list(first[:,1]).count), marker = "*", c = "k")
ax3.scatter(max(set(second[:,0]), key=list(second[:,0]).count), max(set(second[:,1]), key=list(second[:,1]).count), marker = "*", c = "k")
# Central scatter plot.

# X distribution.
sns.distplot(data[:,0], ax = ax1, bins = bins)
ax1.scatter(np.median(data[:,0]),0, label = "median", marker = "s", c = "r")
ax1.scatter(np.mean(data[:,0]), 0, label = "mean", marker = "o", c = "magenta")
ax1.scatter(max(set(first[:,0]), key=list(first[:,0]).count),0, label = "modes", marker = "*", c = "k")
ax1.scatter(max(set(second[:,0]), key=list(second[:,0]).count),0, label="_nolegend_", marker = "*", c = "k")
ax1.legend()
# X distribution.

# Y distribution.
sns.distplot(data[:,1], ax = ax4, vertical = True, bins = bins)
ax4.scatter(0,max(set(first[:,1]), key=list(first[:,1]).count), marker = "*", c = "k")
ax4.scatter(0,max(set(second[:,1]), key=list(second[:,1]).count), marker = "*", c = "k")
ax4.scatter(0, np.mean(data[:,1]), marker = "o", c = "magenta")
ax4.scatter(0,np.median(data[:,1]), marker = "s", c = "r");
# Y distribution.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_302/760193949.py in <module>
#      10
#      11 # Central scatter plot.
# ---> 12 ax3.scatter(data[:,0],data[:,1], s = .5, alpha = .5)
#      13 sns.kdeplot(data[:,0], data[:,1],n_levels=10, cmap="viridis_r", ax = ax3, bw = 1)
#      14 ax3.scatter(np.mean(data[:,0]),np.mean(data[:,1]), marker = "o", color = "magenta")
#
# NameError: name 'data' is not defined

# %%
train_transform = transforms.Compose(
    [
        transforms.Resize(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.ToTensor(),
        # transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    ]
)

test_transform = transforms.Compose(
    [
        transforms.Resize(224),
        transforms.ToTensor(),
        # transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    ]
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
trainset = HistoDataset(
    root='/root/autodl-tmp/RandStainNA-master/classification/100K-NONORM-png/train0',
    transform=train_transform,
)
train_loader = DataLoader(
            dataset=trainset,
            batch_size=89434,
            shuffle=True,
#             num_workers=15,
        )        
testset = HistoDataset(
    root='/root/autodl-tmp/RandStainNA-master/classification/100K-NONORM-png/test',
    transform=test_transform,
)

test_loader = DataLoader(
            dataset=testset,
            batch_size=6399,
            shuffle=True,
#             num_workers=15,
        )      

for img, label in tqdm(test_loader):
    x = rgb_to_hsv(img).to(device)
    mu = x.mean(axis=(2, 3)).to(device)
    sigma = x.std(axis=(2, 3)).to(device)
    mu0 = mu.mean(axis=0).to(device)
    sigma0 = sigma.mean(axis=0).to(device)
    print(mu0)
    print(sigma0)
# Out:
#   0%|          | 0/6363 [00:00<?, ?it/s]

# %%
meanL = mu[:,0].flatten().cpu().numpy()
stdL = sigma[:,0].flatten().cpu().numpy()
x1 = np.linspace(40,90,6)
x2 = np.linspace(5,30,6)
# Figure setup.
fig = plt.figure(figsize=(6, 24))
gs = GridSpec(4, 1)
ax1 = fig.add_subplot(gs[0])
ax2 = fig.add_subplot(gs[1])
ax3 = fig.add_subplot(gs[2])
ax4 = fig.add_subplot(gs[3])
bins = 100
# Central scatter plot.
sns.distplot(meanL, ax = ax1, bins = bins)

# ax1.scatter(np.median(data[:,0]),0, label = "median", marker = "s", c = "r")
# ax1.scatter(np.mean(data[:,0]), 0, label = "mean", marker = "o", c = "magenta")
# ax1.scatter(max(set(first[:,0]), key=list(first[:,0]).count),0, label = "modes", marker = "*", c = "k")
# ax1.scatter(max(set(second[:,0]), key=list(second[:,0]).count),0, label="_nolegend_", marker = "*", c = "k")
# ax1.legend()
ax1.set_xlabel('Mean of L Channel', fontsize=15)
ax1.set_ylabel('Density', fontsize=15)

ax10 = ax1.twinx()  # this is the important function
ax10.plot(x1,[90.178,91.931,92.073,92.105,91.757,90.794], marker = "s", c = 'g')
ax10.set_ylabel('Accuracy', fontsize=15)
ax1.tick_params(labelsize=15)
ax10.tick_params(labelsize=15)

sns.distplot(stdL, ax = ax2, bins = bins)
ax2.set_xlabel('Standard Deviation of L Channel', fontsize=15)
ax2.set_ylabel('Density', fontsize=15)
ax2.tick_params(labelsize=15)

ax20 = ax2.twinx()  # this is the important function
ax20.plot(x2,[91.442,91.742,91.789,91.947,92.594,90.478], marker = "s", c = 'g')
ax20.set_ylabel('Accuracy', fontsize=15)
ax20.tick_params(labelsize=15)

# ax3.plot(x1,[90.178,91.931,92.073,92.105,91.757,90.794])
# ax3.set_xlabel('E(L)')
# ax3.set_ylabel('accuracy')

# ax2.plot(x2,[91.442,91.742,91.789,91.947,92.594,90.478])
# ax4.set_xlabel('Var(L)')
# ax4.set_ylabel('accuracy')
# Out:
# /tmp/ipykernel_579/1009715318.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(meanL, ax = ax1, bins = bins)
# /tmp/ipykernel_579/1009715318.py:30: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(stdL, ax = ax2, bins = bins)

# %%
# !python E_V_change.py
# Out:
# [[[ 40.423584  22.953125 -27.796875]
#   [ 27.331543  24.953125 -29.15625 ]
#   [ 23.736572  31.109375 -21.828125]
#   ...
#   [ 71.710205  28.234375 -12.296875]
#   [ 80.74341   23.328125  -8.921875]
#   [ 80.70679   23.328125 -10.0625  ]]
#
#  [[ 44.04297   22.40625  -26.28125 ]
#   [ 27.868652  25.203125 -28.921875]
#   [ 22.064209  30.5      -23.203125]
#   ...
#   [ 65.979004  30.421875 -12.71875 ]
#   [ 75.01831   24.015625 -11.15625 ]
#   [ 82.13501   20.484375 -10.09375 ]]
#
#  [[ 53.619385  20.140625 -21.828125]
#   [ 33.007812  22.375    -28.90625 ]
#   [ 23.248291  28.71875  -25.953125]
#   ...
#   [ 61.51123   32.203125 -14.5     ]
#   [ 67.93823   26.953125 -13.6875  ]
#   [ 74.798584  21.953125 -12.078125]]
#
#  ...
#
#  [[ 34.954834  38.53125  -19.90625 ]
#   [ 37.78076   38.703125 -21.03125 ]
#   [ 43.927002  39.734375 -18.328125]
#   ...
#   [ 53.344727  38.40625  -15.515625]
#   [ 55.88379   43.96875  -13.203125]
#   [ 62.768555  40.84375  -11.828125]]
#
#  [[ 36.2854    36.921875 -20.328125]
#   [ 41.601562  41.5625   -17.078125]
#   [ 44.458008  40.859375 -16.875   ]
#   ...
#   [ 56.414795  34.828125 -14.296875]
#   [ 55.163574  38.234375 -16.78125 ]
#   [ 48.120117  40.0625   -15.34375 ]]
#
#  [[ 38.623047  37.5625   -19.078125]
#   [ 40.43579   41.5625   -16.765625]
#   [ 41.192627  38.96875  -19.      ]
#   ...
#   [ 57.50122   38.046875 -14.28125 ]
#   [ 60.308838  36.390625 -16.296875]
#   [ 51.739502  35.28125  -18.078125]]]
# (224, 224)
# 60.818615 29.882748 -13.613625 19.134598 11.555011 6.083248
# [[ 52.81478   35.709587  31.012636 ...  93.69181  105.493996 105.44615 ]
#  [ 57.54363   36.41134   28.827637 ...  86.203804  98.01396  107.312164]
#  [ 70.05554   43.125828  30.37468  ...  80.3665    88.7636    97.72688 ]
#  ...
#  [ 45.669674  49.361847  57.392113 ...  69.69669   73.01406   82.00925 ]
#  [ 47.408104  54.35385   58.085896 ...  73.70784   72.073074  62.870564]
#  [ 50.46232   52.83073   53.81956  ...  75.12729   78.79554   67.59941 ]]

# %%
a = torch.tensor([1,2])
b = torch.tensor([1,3])
print(a**b)
# Out:
# tensor([1, 8])

# %%
a = torch.tensor([-0.5,0.7])
a = torch.where(a<0,torch.tensor([0]),a)
print(a)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_15566/966268738.py in <module>
#       1 a = torch.tensor([-0.5,0.7])
# ----> 2 a = torch.where(a<0,torch.tensor([0]),a)
#       3 print(a)
#
# RuntimeError: expected scalar type long int but found float
